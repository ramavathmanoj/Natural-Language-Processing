# %%
import streamlit as st
from transformers import pipeline, AutoTokenizer, TFGPT2LMHeadModel

# Set Streamlit page title
st.set_page_config(page_title="🤖 Hugging Face LLM Chatbot")

# Title of the app
st.title("🤗 Hugging Face Chatbot using GPT-2")

# Load tokenizer and model from Hugging Face Hub
@st.cache_resource
def load_model():
    tokenizer = AutoTokenizer.from_pretrained("gpt2")
    model = TFGPT2LMHeadModel.from_pretrained("gpt2", from_pt=True)
    generator = pipeline("text-generation", model=model, tokenizer=tokenizer)
    return generator

generator = load_model()

# Text input from the user
with st.form("chat_form"):
    user_input = st.text_area("Enter your question:")
    submitted = st.form_submit_button("Ask")

    if submitted and user_input:
        with st.spinner("Generating response..."):
            response = generator(user_input, max_length=100, do_sample=True, top_k=50, top_p=0.95)[0]['generated_text']
            st.markdown("### 💬 Chatbot Response:")
            st.success(response)
# Out:
# 2025-07-08 16:34:43.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:34:43.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:34:43.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:34:43.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:34:43.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:34:43.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:34:43.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:34:43.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:34:44.550 Thread 'Thread-18': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:34:44.573 Thread 'Thread-18': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:34:44.575 Thread 'Thread-18': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# pytorch_model.bin:   0%|          | 0.00/548M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFGPT2LMHeadModel.
#
# All the weights of TFGPT2LMHeadModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.
# Device set to use 0
# 2025-07-08 16:35:29.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:35:29.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:35:29.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:35:29.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:35:29.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:35:29.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:35:29.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:35:29.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:35:29.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:35:29.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:35:29.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:35:29.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:35:29.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:35:29.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:35:29.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:35:29.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:35:29.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 16:35:29.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
